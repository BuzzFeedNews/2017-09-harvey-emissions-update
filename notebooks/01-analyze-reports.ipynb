# %% [markdown]
# # Analyze parsed reports
#
# This notebook analyzes the Texas Commission on Environmental Quality's Air Emission Event Reporting Database data parsed in the previous step. It focuses on reports of events since Aug. 23 in the Texas counties subject to the state's Harvey disaster declaration.

# %%
import pandas as pd

# %%
DISASTER_DECLARATION_COUNTIES = open("../inputs/disaster-declaration-counties.txt")\
    .read().strip()\
    .split("\n")
len(DISASTER_DECLARATION_COUNTIES)
# Out:
# 54

# %% [markdown]
# ## Load the data

# %%
reports = pd.read_csv(
    "../outputs/report-metadata-raw.csv",
)
reports["Event began"] = pd.to_datetime(reports["Event began"])
reports["Event ended"] = pd.to_datetime(reports["Event ended"], errors="coerce")

# %%
reports.head()
# Out:
#   Action taken                                              Cause  \
# 0          NaN  Unauthorized discharge at 150 Persimmon Manhol...
# 1          NaN  Chlorinated Excursion; Cleared Private Line; C...
# 2          NaN                     Scheduled for Further Repairs;
# 3          NaN  Unauthorized Discharge at 1016 Applewood manho...
# 4          NaN  Chlorinated Excursion; Cleared Private Line; C...
#
#           City, County Emissions estimation method         Event began  \
# 0      BAYTOWN, HARRIS                         NaN 2017-08-10 20:43:00
# 1      HOUSTON, HARRIS                         NaN 2017-08-04 00:00:00
# 2      HOUSTON, HARRIS                         NaN 2017-08-04 00:00:00
# 3  FRIENDSWOOD, HARRIS                         NaN 2017-08-14 19:00:00
# 4      HOUSTON, HARRIS                         NaN 2017-08-04 00:00:00
#
#           Event ended                  Physical location  \
# 0 2017-08-10 23:45:00                                NaN
# 1 2017-08-04 00:00:00                                NaN
# 2 2017-08-04 00:00:00                                NaN
# 3 2017-08-14 22:00:00                                NaN
# 4 2017-08-04 00:00:00  9400 White Chapel Ln, Houston, TX
#
#   Regulated entity RN number   Regulated entity name This is based on the  \
# 0                RN101611457           EAST DISTRICT         FINAL REPORT
# 1                RN101607596            BELTWAY WWTP         FINAL REPORT
# 2                RN101612158            FWSD 23 WWTP         FINAL REPORT
# 3                RN102183340  BLACKHAWK REGIONAL WTP         FINAL REPORT
# 4                RN101614113      KEEGANS BAYOU WWTP         FINAL REPORT
#
#   Type(s) of air emissions event  report_id
# 0              WASTEWATER BYPASS     265500
# 1              WASTEWATER BYPASS     265502
# 2              WASTEWATER BYPASS     265503
# 3              WASTEWATER BYPASS     265504
# 4              WASTEWATER BYPASS     265505

# %% [markdown]
# ## Separate city and county

# %%
reports["City"] = reports["City, County"].apply(lambda x: x.split(", ")[0])
reports["City"].value_counts().head(10)
# Out:
#                   180
# HOUSTON           144
# SAN ANTONIO        47
# GOLDSMITH          35
# CRANE              33
# CORPUS CHRISTI     23
# AUSTIN             19
# PASADENA           19
# PORT ARTHUR        18
# BAYTOWN            15
# Name: City, dtype: int64

# %%
reports["County"] = reports["City, County"].apply(lambda x: x.split(", ")[1])
reports["County"].value_counts().head(10)
# Out:
# HARRIS       244
# BEXAR         49
# CRANE         39
# ECTOR         38
# JEFFERSON     36
# GALVESTON     33
# TARRANT       29
# NUECES        28
# BRAZORIA      27
# DALLAS        25
# Name: County, dtype: int64

# %% [markdown]
# ### Here are the counties we're not analyzing, as a data-check

# %%
print("\n".join(sorted(reports[~reports["County"].str.upper().isin(DISASTER_DECLARATION_COUNTIES)]["County"].unique())))
# Out:
# ANDERSON
# ANDREWS
# ANGELINA
# BELL
# BOSQUE
# BOWIE
# BURNET
# CAMP
# CASS
# CASTRO
# CHEROKEE
# COCHRAN
# COLLIN
# COMANCHE
# CRANE
# CULBERSON
# DALLAS
# DAWSON
# DENTON
# DIMMIT
# DUVAL
# EASTLAND
# ECTOR
# EL PASO
# ELLIS
# ERATH
# FALLS
# FANNIN
# FREESTONE
# FRIO
# GAINES
# GLASSCOCK
# GRAYSON
# HARRISON
# HAYS
# HENDERSON
# HIDALGO
# HILL
# HOCKLEY
# HOOD
# HOUSTON
# HOWARD
# HUNT
# HUTCHINSON
# JOHNSON
# JONES
# KAUFMAN
# KENT
# LA SALLE
# LIMESTONE
# LUBBOCK
# MARTIN
# MASON
# MCLENNAN
# MCMULLEN
# MIDLAND
# MILAM
# MITCHELL
# MONTAGUE
# NACOGDOCHES
# NOLAN
# ORANGE
# PALO PINTO
# PANOLA
# PARKER
# PECOS
# POTTER
# RANDALL
# REAGAN
# REEVES
# ROCKWALL
# RUNNELS
# RUSK
# SABINE
# SAN AUGUSTINE
# SCHLEICHER
# SHELBY
# SHERMAN
# SMITH
# STEPHENS
# TARRANT
# TAYLOR
# TITUS
# TOM GREEN
# TRAVIS
# TRINITY
# UPTON
# VAN ZANDT
# WARD
# WEBB
# WHEELER
# WILBARGER
# WILLIAMSON
# WINKLER
# WISE
# YOAKUM

# %% [markdown]
# ## Count by type

# %%
REPORT_IDS_TO_IGNORE = [ int(line.split("#")[0].strip())
    for line in open("../inputs/reports-to-ignore.txt") ]
REPORT_IDS_TO_IGNORE
# Out:
# [266113,
#  266073,
#  266136,
#  266156,
#  266246,
#  267665,
#  266648,
#  267063,
#  266274,
#  266338,
#  266966,
#  267240,
#  267389,
#  267394,
#  267398,
#  267624,
#  266675,
#  267677,
#  267253,
#  266301,
#  266266]

# %%
reports_of_interest = reports[
    reports["County"].str.upper().isin(DISASTER_DECLARATION_COUNTIES) &
    ~reports["report_id"].isin(REPORT_IDS_TO_IGNORE) &
    (reports["Event began"] >= "2017-08-23") &
    (reports["Type(s) of air emissions event"].isin([ "EMISSIONS EVENT", "AIR SHUTDOWN", "AIR STARTUP" ]))
]

# %% [markdown]
# ## Summarize report data

# %%
reports_of_interest["Regulated entity RN number"].nunique()
# Out:
# 53

# %%
reports_of_interest.groupby([ "County", "Type(s) of air emissions event" ])\
    .size()\
    .unstack()\
    .fillna(0)\
    .astype(int)\
    .assign(total=lambda x: x.sum(axis=1))\
    .sort_values(["total"], ascending=False)
# Out:
# Type(s) of air emissions event  AIR SHUTDOWN  AIR STARTUP  EMISSIONS EVENT  \
# County
# HARRIS                                     3            2               27
# JEFFERSON                                  4            5               12
# NUECES                                     2            3               12
# BRAZORIA                                   1            2                7
# CHAMBERS                                   0            3                4
# CALHOUN                                    1            3                1
# VICTORIA                                   1            4                0
# GALVESTON                                  1            1                2
# GRIMES                                     0            0                2
# WASHINGTON                                 0            0                2
# DEWITT                                     0            0                1
# JASPER                                     0            0                1
# LIVE OAK                                   0            0                1
#
# Type(s) of air emissions event  total
# County
# HARRIS                             32
# JEFFERSON                          21
# NUECES                             17
# BRAZORIA                           10
# CHAMBERS                            7
# CALHOUN                             5
# VICTORIA                            5
# GALVESTON                           4
# GRIMES                              2
# WASHINGTON                          2
# DEWITT                              1
# JASPER                              1
# LIVE OAK                            1

# %% [markdown]
# ## Analyze contaminants emitted

# %%
emissions = pd.read_csv("../outputs/report-emissions-raw.csv")\
    .pipe(lambda x: x[x["report_id"].isin(reports_of_interest["report_id"])])
emissions.head()
# Out:
#      report_id contaminant    authorization          limit   amount_released
# 735     266106     Opacity   NSR Permit 813      20.0 % op   6.3 % op (est.)
# 736     266106     Opacity   NSR Permit 812      20.0 % op  0.55 % op (est.)
# 737     266106     Opacity   NSR Permit 812      20.0 % op   7.7 % op (est.)
# 743     266110   Acetylene  19168/PSDTX1226  761.65 LBS/HR  90.77 lbs (est.)
# 744     266110     Benzene  19168/PSDTX1226  761.65 LBS/HR  147.1 lbs (est.)

# %%
emissions["quantity"] = emissions["amount_released"].apply(lambda x: x.split(" ", 1)[0])\
    .replace("Unknown", pd.np.nan)\
    .astype(float)
emissions["quantity"].head()
# Out:
# 735      6.30
# 736      0.55
# 737      7.70
# 743     90.77
# 744    147.10
# Name: quantity, dtype: float64

# %%
emissions["units"] = emissions["amount_released"].apply(lambda x: x.split(" ", 1)[1] if " " in x else None)\
    .replace("Unknown", pd.np.nan)
emissions["units"].head()
# Out:
# 735    % op (est.)
# 736    % op (est.)
# 737    % op (est.)
# 743     lbs (est.)
# 744     lbs (est.)
# Name: units, dtype: object

# %%
emissions["units"].value_counts()
# Out:
# lbs (est.)     1453
# % op (est.)      21
# lbs               2
# LBS/HR            1
# Name: units, dtype: int64

# %%
EMISSIONS_SUMMARY_COLS = [ 
    "report_id",
    "Event began",
    "Event ended",
    "Regulated entity RN number",
    "Regulated entity name",
    "Type(s) of air emissions event",
    "County",
    "contaminant",
    "authorization",
    "limit",
    "quantity",
    "units",
]

# %%
emissions_lbs = emissions[
    emissions["units"].str.contains(r"\blbs")
].pipe(pd.merge, reports, on="report_id")\
    .sort_values(["quantity", "report_id", "contaminant"], ascending=False)\
    [EMISSIONS_SUMMARY_COLS]
    
emissions_lbs.to_csv("../outputs/largest-emissions-in-lbs.csv", index=False)

# %%
emissions_lbs[
    emissions_lbs["quantity"] > 0
]["Regulated entity RN number"].nunique()
# Out:
# 48

# %%
emissions_lbs[
    emissions_lbs["quantity"] > 0
]["report_id"].nunique()
# Out:
# 95

# %%
emissions_lbs.head()
# Out:
#       report_id         Event began         Event ended  \
# 162      266261 2017-08-27 00:00:00 2017-09-06 00:00:00
# 786      266378 2017-08-29 11:50:00 2017-09-01 11:50:00
# 1381     267078 2017-09-08 08:00:00 2017-09-22 08:00:00
# 1379     267078 2017-09-08 08:00:00 2017-09-22 08:00:00
# 1120     266566 2017-09-01 05:00:00 2017-10-01 05:00:00
#
#      Regulated entity RN number                        Regulated entity name  \
# 162                 RN103919817  CHEVRON PHILLIPS CHEMICAL CEDAR BAYOU PLANT
# 786                 RN100217389   FLINT HILLS RESOURCES PORT ARTHUR FACILITY
# 1381                RN100217389   FLINT HILLS RESOURCES PORT ARTHUR FACILITY
# 1379                RN100217389   FLINT HILLS RESOURCES PORT ARTHUR FACILITY
# 1120                RN100221662                EQUISTAR CORPUS CHRISTI PLANT
#
#      Type(s) of air emissions event     County         contaminant  \
# 162                    AIR SHUTDOWN     HARRIS     Carbon Monoxide
# 786                    AIR SHUTDOWN  JEFFERSON     Carbon Monoxide
# 1381                    AIR STARTUP  JEFFERSON  Ethylene (gaseous)
# 1379                    AIR STARTUP  JEFFERSON     Carbon Monoxide
# 1120                    AIR STARTUP     NUECES     Carbon Monoxide
#
#                   authorization           limit  quantity       units
# 162                       1504A  1892.04 LBS/HR  244040.0  lbs (est.)
# 786   No specific Authorization             0.0  240000.0  lbs (est.)
# 1381  No specific authorization             0.0  150000.0  lbs (est.)
# 1379  No specific authorization             0.0  150000.0  lbs (est.)
# 1120               Permit 83864   721.67 LBS/HR  121000.0  lbs (est.)

# %%
emissions_lbs["quantity"].sum()
# Out:
# 5419902.4145000009

# %% [markdown]
# ## Analyze emissions by facility

# %%
emissions_lbs.groupby([ "Type(s) of air emissions event" ])["quantity"].sum() / 1e6
# Out:
# Type(s) of air emissions event
# AIR SHUTDOWN       1.923592
# AIR STARTUP        1.890128
# EMISSIONS EVENT    1.606182
# Name: quantity, dtype: float64

# %%
lbs_grp = emissions_lbs.groupby([ "Regulated entity RN number" ])

lbs_by_entity = pd.DataFrame({
    "Regulated entity name": lbs_grp["Regulated entity name"].first(),
    "County": lbs_grp["County"].first(),
    "quantity_1000s": (lbs_grp["quantity"].sum() / 1000).round(2),
    "contaminants": lbs_grp["contaminant"].apply(lambda x: " • ".join(sorted(x.str.lower().unique()))),
    "report_ids": lbs_grp["report_id"].apply(lambda x: " • ".join(sorted(x.astype(str).str.lower().unique()))),
    "units": "lbs"
}).sort_values(["quantity_1000s", "Regulated entity name"], ascending=False)

lbs_by_entity.to_csv("../outputs/facilities-with-most-emissions-lbs.csv")
lbs_by_entity
# Out:
#                                 County  \
# Regulated entity RN number
# RN100217389                  JEFFERSON
# RN103919817                     HARRIS
# RN100210608                  GALVESTON
# RN102579307                     HARRIS
# RN100825249                   BRAZORIA
# RN102584026                  JEFFERSON
# RN100238708                   BRAZORIA
# RN100221662                     NUECES
# RN100224815                     HARRIS
# RN101619179                   BRAZORIA
# RN100218973                    CALHOUN
# RN100235266                     NUECES
# RN100225945                   BRAZORIA
# RN102450756                  JEFFERSON
# RN102534138                     NUECES
# RN102180486                     HARRIS
# RN100209451                  JEFFERSON
# RN102457520                  JEFFERSON
# RN100211879                     HARRIS
# RN102323268                   CHAMBERS
# RN104964267                  JEFFERSON
# RN100210301                     HARRIS
# RN100209857                  JEFFERSON
# RN102190139                     NUECES
# RN102555166                     NUECES
# RN100219252                  JEFFERSON
# RN102536836                     NUECES
# RN100836329                 WASHINGTON
# RN100542281                     HARRIS
# RN100214386                     NUECES
# RN100238799                     NUECES
# RN100716661                     HARRIS
# RN102212925                     HARRIS
# RN100210319                     HARRIS
# RN100219526                     HARRIS
# RN100219310                     HARRIS
# RN104150123                     HARRIS
# RN100219351                  GALVESTON
# RN100227016                     HARRIS
# RN102984911                   CHAMBERS
# RN101062610                     HARRIS
# RN102561925                  JEFFERSON
# RN100211663                     NUECES
# RN108772245                   BRAZORIA
# RN100634922                  JEFFERSON
# RN102181526                    CALHOUN
# RN106485659                     DEWITT
# RN100214550                     GRIMES
#
#                                                         Regulated entity name  \
# Regulated entity RN number
# RN100217389                        FLINT HILLS RESOURCES PORT ARTHUR FACILITY
# RN103919817                       CHEVRON PHILLIPS CHEMICAL CEDAR BAYOU PLANT
# RN100210608                            MARATHON PETROLEUM TEXAS CITY REFINERY
# RN102579307                                      EXXON MOBIL BAYTOWN REFINERY
# RN100825249                 CHEVRON PHILLIPS CHEMICAL SWEENY OLD OCEAN FAC...
# RN102584026                                       VALERO PORT ARTHUR REFINERY
# RN100238708                                             CHOCOLATE BAYOU PLANT
# RN100221662                                     EQUISTAR CORPUS CHRISTI PLANT
# RN100224815                                                 PASADENA TERMINAL
# RN101619179                                                   SWEENY REFINERY
# RN100218973                                       FORMOSA POINT COMFORT PLANT
# RN100235266                                     FHR CORPUS CHRISTI WEST PLANT
# RN100225945                                     DOW TEXAS OPERATIONS FREEPORT
# RN102450756                                      EXXONMOBIL BEAUMONT REFINERY
# RN102534138                               FLINT HILLS RESOURCES EAST REFINERY
# RN102180486                                              GALENA PARK TERMINAL
# RN100209451                                              PORT ARTHUR REFINERY
# RN102457520                 TOTAL PETRO CHEMICALS & REFINING USA PORT ARTH...
# RN100211879                                               SHELL OIL DEER PARK
# RN102323268                                   ENTERPRISE MONT BELVIEU COMPLEX
# RN104964267                                  TPC GROUP PORT NECHES OPERATIONS
# RN100210301                                               ARKEMA CROSBY PLANT
# RN103919817                                            266261 • 266262   lbs
# RN100210608                                   266376 • 266463 • 266570   lbs
# RN102579307                                            266277 • 266294   lbs
# RN100825249                                            266372 • 267392   lbs
# RN102584026                          266764 • 266817 • 266834 • 267400   lbs
# RN100238708                                   266271 • 266897 • 267010   lbs
# RN100221662                                            266177 • 266566   lbs
# RN100224815                                            266269 • 266556   lbs
# RN101619179                                            266328 • 266848   lbs
# RN100218973                          266110 • 266116 • 266122 • 266124   lbs
# RN100235266                                   266120 • 266353 • 266643   lbs
# RN100225945                                                     266292   lbs
# RN102450756                                            266314 • 266516   lbs
# RN102534138                                   266114 • 266416 • 267024   lbs
# RN102180486                                                     266754   lbs
# RN100209451                                                     266550   lbs
# RN102457520                                                     266549   lbs
# RN100211879                                            266341 • 267012   lbs
# RN102323268                          266280 • 266324 • 266375 • 266483   lbs
# RN104964267                                   266466 • 266761 • 267293   lbs
# RN100210301                 266756 • 266771 • 266778 • 267578 • 267679   lbs
# RN100209857                                                     266458   lbs
# RN102190139                                                     266176   lbs
# RN102555166                                                     266194   lbs
# RN100219252                                            266763 • 267591   lbs
# RN102536836                                                     266767   lbs
# RN100836329                                            266290 • 266367   lbs
# RN100542281                          266423 • 266775 • 266861 • 267468   lbs
# RN100214386                                            266782 • 267021   lbs
# RN100238799                                                     266195   lbs
# RN100716661                                            266264 • 266870   lbs
# RN102212925                                                     266279   lbs
# RN100210319                                                     266329   lbs
# RN100219526                                                     266260   lbs
# RN100219310                                                     266275   lbs
# RN104150123                                                     267064   lbs
# RN100219351                                                     266454   lbs
# RN100227016                                            266267 • 266268   lbs
# RN102984911                                   266707 • 266711 • 267275   lbs
# RN101062610                          266263 • 266276 • 266558 • 266647   lbs
# RN102561925                                                     267579   lbs
# RN100211663                                                     266783   lbs
# RN108772245                                            266382 • 266772   lbs
# RN100634922                                                     266429   lbs
# RN102181526                                                     266571   lbs
# RN106485659                                                     267401   lbs
# RN100214550                                                     267474   lbs

# %% [markdown]
# # Analyze 2015 and 2016 emissions from these same facilities

# %%
historical_report_metadata = pd.read_csv("../outputs/report-metadata-raw-historical.csv")
historical_report_emissions = pd.read_csv("../outputs/report-emissions-raw-historical.csv")

# %% [markdown]
# Emissions in millions of pounds:

# %%
pd.merge(
    historical_report_metadata,
    historical_report_emissions,
    how="left",
    on="report_id"
)\
    .pipe(lambda x: x[x["amount_released"].str.contains(r"\blbs", na=False)])\
    .assign(year=lambda x: pd.to_datetime(x["Event began"]).dt.year)\
    .assign(amt=lambda x: x["amount_released"].apply(lambda x: float(x.split(" ")[0])))\
    .groupby(["year", "This is based on the"])["amt"].sum().unstack() / 1e6
# Out:
# This is based on the  FINAL REPORT  INITIAL REPORT
# year
# 2014                      0.287886             NaN
# 2015                      8.158067        0.064122
# 2016                      5.493888        0.046722

# %% [markdown]
# ---
#
# ---
#
# ---
